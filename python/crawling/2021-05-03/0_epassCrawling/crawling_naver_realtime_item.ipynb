# %%
import selenium
from selenium import webdriver
from bs4 import BeautifulSoup
from bs4 import BeautifulSoup

#----------------------------------------------------------------
# 뷰티플스프는 셀레늄 기본코드에 포함되지 않음.
driver = webdriver.Chrome("C:/Users/User/0_epassCrawling/chromedriver")
driver = webdriver.Chrome("./chromedriver")
# 크롬 드라이버가 설치된 위치
# 같은 경로에 크롬드라이버.exe 파일이 있으면 상대경로로 경로 설정가능.
                           
# URL에 해당하는 웹페이지 서버에 연결.
# 인터넷 자원 위치?
# https://datalab.naver.com/home/sectionSearch.naver
# https://datalab.naver.com/keyword/realtimeList.naver?where=main
driver.get("https://datalab.naver.com/home/sectionSearch.naver")
# beautifulSoup

# 같이 있어야 동작... 이런? 아래거랑 참조해서 합쳐두기
html = driver.page_source
html_parsing = BeautifulSoup(html, "lxml")

# 홈페이지 내용. 셀레늄과도 붙여쓸수있음. 뷰티플스프 코드.
# html = driver.page_source
# print(html)

# html_parsing = BeautifulSoup(html, "lxml")
# print(html_parsing)
html = driver.page_source
html_parsing = BeautifulSoup(html, "lxml")
# print(html_parsing)

# 창 뜨는건 셀레늄에 해당하는기능.
# 닫는것 역시 마찬가지. 셀레늄 기능임.
# 크롤링이 끝나면 닫아줌.
driver.close()

# %%
from datetime import datetime

now = datetime.now()

print(now)
print("%s 년 %s월 %s일 %s시 %s분 %s초"%(now.year, now.month, now.day, now.hour, now.minute, now.second))
# Out:
# 2021-04-30 11:03:39.949634
# 2021 년 4월 30일 11시 3분 39초

# %%
print(html_parsing)

date = html_parsing.select("span", class_="title_cell")<div class="keyword_rank">
# <div class="rank_inner v2">
# <strong class="rank_title">
# <span class="title_cell">2021.04.19.(월)</span>
# </strong>
# <div class="rank_scroll" style="left:0px; width:5000px;">
# <ul class="rank_list">
# <li class="list">
# date =  html_parsing.select("span.date_txt")
# print(date)
# Out:
# <html lang="ko"><head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=1200" name="viewport"/>
# <title>네이버 데이터랩</title>
# <link href="https://ssl.pstatic.net/static.datalab/202104010127/css/datalab.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.datalab/202104010127/css/graph.css" rel="stylesheet" type="text/css"/>
# <link href="https://ssl.pstatic.net/static.datalab/202104010127/img/favicon/android_legacy_xxxhpdi_192x192.png" rel="icon" sizes="192x192"/>
# <link href="https://ssl.pstatic.net/static.datalab/202104010127/img/favicon/android_legacy_xxhpdi_144x144.png" rel="icon" sizes="144x144"/>
# <link href="https://ssl.pstatic.net/static.datalab/202104010127/img/favicon/android_legacy_xhdpi_96x96.png" rel="icon" sizes="96x96"/>
# <link href="https://ssl.pstatic.net/static.datalab/202104010127/img/favicon/android_legacy_hdpi_72X72.png" rel="icon" sizes="72x72"/>
# ...
